# %%
using CairoMakie
include("../src-fig/plotting.jl")
# Out:
# sponge_profile (generic function with 1 method)

# %% [markdown]
# We require a "realistic" mesoscale field. We will use a simulation of baroclinic instability...

# %%
include("../src-fig/figures/initialized.jl")
initialized_BI("profile-med-cooling", range(1, 101, 300), "init-profile-med-cooling.mp4"; fig_kw=(; size=(800, 400)))
# Out:
# 33s / 33s (300 / 300)

# %%
initialized_BI("med-cooling", range(1, 101, 300), "init-med-cooling.mp4"; fig_kw=(; size=(800, 400)))
# Out:
# 24s / 24s (300 / 300)

# %%
initialized_BI("low-cooling", range(1, 101, 300), "init-low-cooling.mp4"; fig_kw=(; size=(800, 400)))
initialized_BI("high-cooling", range(1, 101, 300), "init-high-cooling.mp4"; fig_kw=(; size=(800, 400)))
# Out:
# 24s / 24s (300 / 300)
# 24s / 24s (300 / 300)

# %% [markdown]
# We
