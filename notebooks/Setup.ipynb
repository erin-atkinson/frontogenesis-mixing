# %%
using CairoMakie
include("../src-fig/plotting.jl")
# Out:
# sponge_profile (generic function with 1 method)

# %% [markdown]
# We require a "realistic" mesoscale field. We will use a simulation of baroclinic instability...

# %%
include("../src-fig/figures/initialized.jl")
initialized_BI("tiny-mixing", range(1, 51, 300), "init-tiny-mixing.mp4"; fig_kw=(; size=(800, 400)))
initialized_BI("low-mixing", range(1, 51, 300), "init-low-mixing.mp4"; fig_kw=(; size=(800, 400)))
initialized_BI("med-mixing", range(1, 51, 300), "init-med-mixing.mp4"; fig_kw=(; size=(800, 400)))
initialized_BI("high-mixing", range(1, 51, 300), "init-high-mixing.mp4"; fig_kw=(; size=(800, 400)))
initialized_BI("no-mixing", range(1, 51, 300), "init-no-mixing.mp4"; fig_kw=(; size=(800, 400)))
# Out:
# 126s / 126s (300 / 300)
# 119s / 119s (300 / 300)
# 115s / 115s (300 / 300)
# 116s / 116s (300 / 300)
# 119s / 119s (300 / 300)

# %%
include("../src-fig/figures/video.jl")
gradient_video("tiny-mixing", range(1, 601, 1200), "gradient-tiny-mixing.mp4"; fig_kw=(; size=(800, 400)))
#gradient_video("low-mixing", range(1, 601, 1200), "gradient-low-mixing.mp4"; fig_kw=(; size=(800, 400)))
#gradient_video("med-mixing", range(1, 601, 1200), "gradient-med-mixing.mp4"; fig_kw=(; size=(800, 400)))
gradient_video("high-mixing", range(1, 837, 1674), "gradient-high-mixing.mp4"; fig_kw=(; size=(800, 400)))
#gradient_video("no-mixing", range(1, 201, 400), "gradient-no-mixing.mp4"; fig_kw=(; size=(800, 400)))
# Out:
# 340s / 340s (1200 / 1200)
# 423s / 423s (1674 / 1674)

# %%
include("../src-fig/figures/video.jl")
#save("no-mixing.png", gradient_video("no-mixing", [201], ""; fig_kw=(; size=(800, 400))); px_per_unit=4)
save("low-mixing.png", gradient_video("low-mixing", [601], ""; fig_kw=(; size=(800, 400))); px_per_unit=4)
#save("med-mixing.png", gradient_video("med-mixing", [601], ""; fig_kw=(; size=(800, 400))); px_per_unit=4)
#save("high-mixing.png", gradient_video("high-mixing", [837], ""; fig_kw=(; size=(800, 400))); px_per_unit=4)
#save("tiny-mixing.png", gradient_video("tiny-mixing", [601], ""; fig_kw=(; size=(800, 400))); px_per_unit=4)

# %%
837/600 * 1200
# Out:
# 1674.0
