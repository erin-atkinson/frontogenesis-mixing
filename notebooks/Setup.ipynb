# %%
using CairoMakie
include("../src-fig/plotting.jl")
# Out:
# [ Info: Oceananigans will use 4 threads
# sponge_profile (generic function with 1 method)

# %% [markdown]
# We require a "realistic" mesoscale field. We will use a simulation of baroclinic instability...

# %%
include("../src-fig/figures/initialized.jl")
#initialized_BI("low-cooling", range(1, 61, 300), "init-low-cooling.mp4"; fig_kw=(; size=(800, 400)))
#initialized_BI("med-cooling", range(1, 61, 300), "init-med-cooling.mp4"; fig_kw=(; size=(800, 400)))
#initialized_BI("high-cooling", range(1, 61, 300), "init-high-cooling.mp4"; fig_kw=(; size=(800, 400)))
initialized_BI("no-mixing", range(1, 61, 61), "init-no-mixing.mp4"; fig_kw=(; size=(800, 400)))
# Out:
# 4s / 4s (61 / 61)
